# %% [markdown]
# Lesson 01 - Section 1.2
# =======================
#
# **Author:** Marcos Bujosa

# %% [markdown]
# $
# \newcommand{\R}[1][{}]{{\mathbb{R}}^{#1}}
# \newcommand{\Z}[1][{}]{{\mathbb{Z}}^{#1}}
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# \newcommand{\getItem}{{\mid}}
# \newcommand{\getitemR}[1]{\getItem{#1}}
# \newcommand{\getitemL}[1]{{#1}\getItem}
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# \newcommand{\elemR}[2]{{#1}^{\phantom{\T}}_{\getitemR{#2}}}
# \newcommand{\elemRP}[2]{{\big(#1\big)}^{\phantom{\T}}_{\getitemR{#2}}}
# \newcommand{\elemRPE}[2]{\big({#1}^{\phantom{\T}}_{\getitemR{#2}}\big)}
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# \newcommand{\elemL}[2]  { {\vphantom{#1}}_{ \getitemL{#2}} {#1} }
# \newcommand{\elemLP}[2] { \elemL{\!\big({#1}\big)}{#2} }
# \newcommand{\elemLPE}[2]{ \big(\elemL{#1}{#2}\big) }
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# \newcommand{\Vect}[2][{}]{{\boldsymbol{#2}}_{#1}}
# \newcommand{\eleVR}[2]  {\elemR  {\Vect{#1}}{#2}}      % con subindices
# \newcommand{\eleVRP}[2] {\elemRP {\Vect{#1}}{#2}}      % con subindices y paréntesis interior
# \newcommand{\eleVRPE}[2]{\elemRPE{\Vect{#1}}{#2}}      % con subindices y paréntesis exterior
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# \newcommand{\VectC}[2]  {\elemR  {\Mat{#1}}{#2}}         % con subindices
# \newcommand{\VectCP}[2] {\elemRP {\Mat{#1}}{#2}}       % con subindices y paréntesis
# \newcommand{\VectCPE}[2]{\elemRPE{\Mat{#1}}{#2}}       % con subindices y paréntesis exterior
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# \newcommand{\VectF}[2]  {\elemL  {\Mat{#1}}{#2}}         % con subindices
# \newcommand{\VectFP}[2] {\elemLP {\Mat{#1}}{#2}}       % con subindices y paréntesis
# \newcommand{\VectFPE}[2]{\elemLPE{\Mat{#1}}{#2}}       % con subindices y paréntesis exterior
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# \newcommand{\mat}[1]{\mathbf{#1}}
# %\newcommand{\mat}[1]{\boldsymbol{#1}}                 % hace cursiva, no me gusta para matriz
# \newcommand{\Mat} [2][{}]{{\mat{#2}}_{#1}}
# \newcommand{\T}{\intercal}
# \newcommand{\MatT}[2][{}]{{\mat{#2}}^{\T}_{#1}}
# \newcommand{\VectCC}[2][{}]   {\elemRR {\Mat{#2}}{#1}}   % con ()
# \newcommand{\VectCCC}[2][{}]  {\elemRRR{\Mat{#2}}{#1}}   % con texto "col"
# %SELECCIÓNA de FILAS y COlUMNAS DE UNA MATRIZ TRANSPUESTA PARA GENERAR UN VECTOR DE Rn
# \newcommand{\VectTC}[2][{}]   {\elemR{\MatT{#2}\!}{#1}}  % con subindices
# \newcommand{\VectTCC}[2][{}]  {\elemRR{ \MatT{#2}}{#1}}  % con ()
# \newcommand{\VectTCCC}[2][{}] {\elemRRR{\MatT{#2}}{#1}}  % con texto "col"
# \newcommand{\dotprod}[2][{}] {\Vect{#1}\cdot\Vect{#2}}
# \newcommand{\concat}{\mathbin{-\mkern-9.5mu\lVert}}
# $
#
# To use [NAcAL](https://github.com/mbujosab/nacallib), it is necessary to import the module `nacal`.

# %%
from nacal import *

# %% [markdown]
# This line of code allows access to the videos on YouTube.

# %%
from IPython.display import YouTubeVideo

# %% [markdown]
# *First, watch the following video and read the [Section 1.2](https://mbujosab.github.io/CursoDeAlgebraLineal/libro.pdf#section.1.2) of Lesson 1 from the book*
# ([https://mbujosab.github.io/CursoDeAlgebraLineal](https://mbujosab.github.io/CursoDeAlgebraLineal))

# %%
YouTubeVideo('LvcerzXX3IM')  # run this block of code to watch the video (but DO NOT DO IT DURING CLASS)

# %% [markdown]
# ## Vector Addition

# %% [markdown]
# Generate the vectors $\Vect{a}$ and $\Vect{b}$:
#
# -   The vector $\Vect{a}$ is formed by the list of numbers: 1, 4, 9, 2.
# -   The vector $\Vect{b}$ is formed by the list of numbers: 1, 2, 1, 0.

# %%
a = Vector([1, 4, 9, 2])
b = Vector([1, 2, 1, 0])

# %% [markdown]
# Add both vectors:

# %%
a + b

# %% [markdown]
# Then, obtain the third component of the sum of both: $\quad \elemR{(\Vect{a}+\Vect{b})}{3}$.

# %%
(a + b)|3

# %% [markdown]
# Now add the third component of $\Vect{a}$ with the third of $\Vect{b}$: $\quad \eleVRPE{a}{3}+\eleVRPE{b}{3}$.
# Verify that you get the same result as in the previous cell.
# What is this property called? (*you will find the name of the property in the [book](https://mbujosab.github.io/CursoDeAlgebraLineal/libro.pdf#section.1.2)*)

# %%
(a|3) + (b|3)

# %% [markdown]
# ### Order of Operations and the Need for Parentheses

# %% [markdown]
# Now try removing the parentheses from the previous expression and run the code
# (*remove the hashtag `#` and run the following code to see it*).

# %%
# a|3 + b|3

# %% [markdown]
# Python will throw an error because it reads and executes operations sequentially from left to right: therefore, when it reaches the symbol `+`, it tries to add vector $\Vect{b}$ to the third component of $\Vect{a}$ (the number `9` you have already calculated), but the addition of numbers and vectors is not defined, resulting in an error. Thus, it is necessary to use parentheses to indicate the correct order of operations. This allows you to calculate first what is inside the parentheses and then perform the addition of the two results.
#
# Note that when we humans read $\;\eleVR{a}{3}+\eleVR{b}{3},\;$ we mentally interpret it as $\;\eleVRPE{a}{3}+\eleVRPE{b}{3};\;$, but Python requires you to clearly indicate the order of operations with parentheses.
#
# When expressions are complex, even humans need parentheses for proper interpretation. Whenever you write a mathematical expression and have doubts, it is better to use parentheses. Remember that, when working with Python, operations are executed left to right, and therefore, parentheses are usually necessary.

# %% [markdown]
# ### Geometric Interpretation of Addition

# %%
YouTubeVideo('kSgd-davYhw')  # run this block of code to watch the video (but DO NOT DO IT DURING CLASS)

# %% [markdown]
# ## Scalar Multiplication of a Vector

# %%
YouTubeVideo('SG4ZwRAIQLY')  # run this block of code to watch the video (but DO NOT DO IT DURING CLASS)

# %% [markdown]
# The same occurs with multiplication. We understand the expression: $$2\Vect{a}$$ because we actually interpret it as: $$2\cdot\Vect{a}$$ (note the point indicating the *product*).
# Python does not work this way. If you type `2a`, Python will show you an error.
# Check it in the following cell:

# %%
# 2a

# %% [markdown]
# Python explicitly requires the indication of the multiplication operation with the symbol `*`.

# %%
2*a

# %% [markdown]
# *Note*: As programmed in the module [NAcAL](https://github.com/mbujosab/nacallib), multiplication is allowed on both sides&#x2026;
# this maintains the left associativity of the selector operator (as explained in the [book](https://mbujosab.github.io/CursoDeAlgebraLineal/libro.pdf#subsection.1.4.4)).

# %%
a*2

# %% [markdown]
# But note that an expression like $\Vect{x}2$ never appears in textbooks.
# The conventional way to write this product is $2\Vect{x}$, that is, *always with the coefficient in front*.

# %% [markdown]
# Obtain the third component of double the vector $\Vect{a}$, that is: $\elemRP{2\Vect{a}}{3}$

# %% [markdown]
# and now obtain the third component of $\Vect{a}$ and multiply it by 2: $\quad 2\elemRPE{\Vect{a}}{3}$.

# %% [markdown]
# Observe that in both cases you obtain the same result.
# What is this property called? (*you will find the answer in the [book](https://mbujosab.github.io/CursoDeAlgebraLineal/libro.pdf#section.1.2)*)
#
# We have just established that the selector operator has two important properties (*one for <u>addition</u> and another for <u>multiplication</u>*) that make it a *linear operator* ¿?
# (*Again, you will find the answer in the [book](https://mbujosab.github.io/CursoDeAlgebraLineal/libro.pdf#section.1.2)*)

# %% [markdown]
# ### Order of Operations and the Need for Parentheses

# %% [markdown]
# Think about how [NAcAL](https://github.com/mbujosab/nacallib) evaluates the following expressions:
#
# -   `(3*b)|2`
# -   `3*(b|2)`
# -   `3*b|2`
#
# Verify if your intuition is confirmed by executing the code for each expression in the cells below.

# %% [markdown]
# What problem does the expression `b+b|2` have? (literally $\Vect{b}+\eleVR{b}{2}$). In this case, does the problem lie with Python? Or does it lie with us?
