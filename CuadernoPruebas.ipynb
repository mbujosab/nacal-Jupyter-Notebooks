# %% [markdown]
# Cuaderno electrónico de pruebas
# ===============================
#
# **Author:** Marcos Bujosa

# %% [markdown]
# $
# \newcommand{\R}[1][{}]{{\mathbb{R}}^{#1}}
# \newcommand{\Z}[1][{}]{{\mathbb{Z}}^{#1}}
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# \newcommand{\getItem}{{\mid}}
# \newcommand{\getitemR}[1]{\getItem{#1}}
# \newcommand{\getitemL}[1]{{#1}\getItem}
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# \newcommand{\elemR}[2]{{#1}^{\phantom{\T}}_{\getitemR{#2}}}
# \newcommand{\elemRP}[2]{{\big(#1\big)}^{\phantom{\T}}_{\getitemR{#2}}}
# \newcommand{\elemRPE}[2]{\big({#1}^{\phantom{\T}}_{\getitemR{#2}}\big)}
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# \newcommand{\elemL}[2]  { {\vphantom{#1}}_{ \getitemL{#2}} {#1} }
# \newcommand{\elemLP}[2] { \elemL{\!\big({#1}\big)}{#2} }
# \newcommand{\elemLPE}[2]{ \big(\elemL{#1}{#2}\big) }
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# \newcommand{\Vect}[2][{}]{{\boldsymbol{#2}}_{#1}}
# \newcommand{\eleVR}[2]  {\elemR  {\Vect{#1}}{#2}}      % con subindices
# \newcommand{\eleVRP}[2] {\elemRP {\Vect{#1}}{#2}}      % con subindices y paréntesis interior
# \newcommand{\eleVRPE}[2]{\elemRPE{\Vect{#1}}{#2}}      % con subindices y paréntesis exterior
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# \newcommand{\VectC}[2]  {\elemR  {\Mat{#1}}{#2}}         % con subindices
# \newcommand{\VectCP}[2] {\elemRP {\Mat{#1}}{#2}}       % con subindices y paréntesis
# \newcommand{\VectCPE}[2]{\elemRPE{\Mat{#1}}{#2}}       % con subindices y paréntesis exterior
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# \newcommand{\VectF}[2]  {\elemL  {\Mat{#1}}{#2}}         % con subindices
# \newcommand{\VectFP}[2] {\elemLP {\Mat{#1}}{#2}}       % con subindices y paréntesis
# \newcommand{\VectFPE}[2]{\elemLPE{\Mat{#1}}{#2}}       % con subindices y paréntesis exterior
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# \newcommand{\mat}[1]{\mathbf{#1}}
# %\newcommand{\mat}[1]{\boldsymbol{#1}}                 % hace cursiva, no me gusta para matriz
# \newcommand{\Mat} [2][{}]{{\mat{#2}}_{#1}}
# \newcommand{\T}{\intercal}
# \newcommand{\MatT}[2][{}]{{\mat{#2}}^{\T}_{#1}}
# \newcommand{\VectCC}[2][{}]   {\elemRR {\Mat{#2}}{#1}}   % con ()
# \newcommand{\VectCCC}[2][{}]  {\elemRRR{\Mat{#2}}{#1}}   % con texto "col"
# %SELECCIÓNA de FILAS y COlUMNAS DE UNA MATRIZ TRANSPUESTA PARA GENERAR UN VECTOR DE Rn
# \newcommand{\VectTC}[2][{}]   {\elemR{\MatT{#2}\!}{#1}}  % con subindices
# \newcommand{\VectTCC}[2][{}]  {\elemRR{ \MatT{#2}}{#1}}  % con ()
# \newcommand{\VectTCCC}[2][{}] {\elemRRR{\MatT{#2}}{#1}}  % con texto "col"
# \newcommand{\dotprod}[2][{}] {\Vect{#1}\cdot\Vect{#2}}
# \newcommand{\concat}{\mathbin{-\mkern-9.5mu\lVert}}
# \newcommand{\SEL}[2] { \Mat{#1}\Vect{x}=\Vect{#2} }
# \newcommand{\EV}[1]{\mathcal{#1}}
# \newcommand{\SV}[1]{\mathsf{#1}}
# $
#
# Lo primero es cargar a librería, que se instala con `pip install nacal`

# %%
from nacal import *

# %% [markdown]
# ## Distintos tipos de números y variables simbólicas

# %% [markdown]
# El módulo NAcAL no solo trabaja con números enteros, o de coma flotante, también con fracciones, e incluso con variables simbólicas, pues usa el módulo [SymPy]([https://www.sympy.org/en/index.html](https://www.sympy.org/en/index.html)).
# Por ejemplo

# %%
a = sympy.symbols('a')               # Variable simbólica
1 + .02 + fracc(1,2) + a + sympy.pi  # entero +  coma flotante + racional + Variable simbólica + irracional

# %%
x, y, z = sympy.symbols('x y z')

# %%
x = Vector([x,y,z])
x

# %%
a * x + sympy.sqrt(2)* x            # Vector con variables simbólicas

# %% [markdown]
# ## Sistema de ecuaciones

# %%
b1, b2, b3 = sympy.symbols('b_1 b_2 b_3')

# %%
b = Vector([b1, b2, b3])

# %%
A = Matrix([[1,2,2,2],[2,4,6,8],[3,6,8,10]])
A

# %%
TrC = SEL(A,b, True).TrC
E = I(5) & TrC
E

# %% [markdown]
# #### Solución particular

# %%
xp = slice(1,4) | E | 0   # los cuatro primeros números de la última columna
xp

# %%
A * xp

# %% [markdown]
# ### Dando valores

# %%
b.subs([(b1,1), (b2,5), (b3,6)])

# %%
SEL(A, b.subs([(b1,1), (b2,5), (b3,6)]), 1)

# %%
SEL(A, b.subs([(b1,-sympy.sqrt(3)), (b2,sympy.pi), (b3,sympy.pi-sympy.sqrt(3))]), 1)

# %%
xp = SEL(A, b.subs([(b1,-sympy.sqrt(3)), (b2,sympy.pi), (b3,sympy.pi-sympy.sqrt(3))]), 1).solP
xp

# %%
A * xp

# %% [markdown]
# #### soluciones especiales

# %%
A * Vector([-2,1,0,0])

# %%
A * (slice(1,4) | E | 4)    # los paréntesis son importantes aquí

# %%
K = A.copy() & TrC   # Forma pre-escalonada de A.

# Si K tiene columnas nulas, las correspondientes de E son soluciones a Ax=0

SolEspeciales = Sistema( [ slice(1,A.n)|E|j  for j,v in enumerate(K) if v.es_nulo() ] )

SolEspeciales

# %% [markdown]
# ### Otro ejemplo (el "testigo" siembre debe ser un 1 al final)

# %%
A = Matrix([[3,2],[6,5],[9,8]])
A

# %%
b=Vector([1,4,7])
b

# %%
A.sel(b, True)

# %%
A * Vector([-3,6])  # tres veces b
