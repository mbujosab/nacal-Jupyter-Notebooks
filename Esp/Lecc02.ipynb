# %% [markdown]
# Lección 02
# ==========
#
# **Author:** Marcos Bujosa

# %% [markdown]
# $
# \newcommand{\R}[1][{}]{{\mathbb{R}}^{#1}}
# \newcommand{\Z}[1][{}]{{\mathbb{Z}}^{#1}}
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# \newcommand{\getItem}{{\mid}}
# \newcommand{\getitemR}[1]{\getItem{#1}}
# \newcommand{\getitemL}[1]{{#1}\getItem}
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# \newcommand{\elemR}[2]{{#1}^{\phantom{\T}}_{\getitemR{#2}}}
# \newcommand{\elemRP}[2]{{\big(#1\big)}^{\phantom{\T}}_{\getitemR{#2}}}
# \newcommand{\elemRPE}[2]{\big({#1}^{\phantom{\T}}_{\getitemR{#2}}\big)}
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# \newcommand{\elemL}[2]  { {\vphantom{#1}}_{ \getitemL{#2}} {#1} }
# \newcommand{\elemLP}[2] { \elemL{\!\big({#1}\big)}{#2} }
# \newcommand{\elemLPE}[2]{ \big(\elemL{#1}{#2}\big) }
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# \newcommand{\Vect}[2][{}]{{\boldsymbol{#2}}_{#1}}
# \newcommand{\eleVR}[2]  {\elemR  {\Vect{#1}}{#2}}      % con subindices
# \newcommand{\eleVRP}[2] {\elemRP {\Vect{#1}}{#2}}      % con subindices y paréntesis interior
# \newcommand{\eleVRPE}[2]{\elemRPE{\Vect{#1}}{#2}}      % con subindices y paréntesis exterior
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# \newcommand{\VectC}[2]  {\elemR  {\Mat{#1}}{#2}}         % con subindices
# \newcommand{\VectCP}[2] {\elemRP {\Mat{#1}}{#2}}       % con subindices y paréntesis
# \newcommand{\VectCPE}[2]{\elemRPE{\Mat{#1}}{#2}}       % con subindices y paréntesis exterior
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# \newcommand{\VectF}[2]  {\elemL  {\Mat{#1}}{#2}}         % con subindices
# \newcommand{\VectFP}[2] {\elemLP {\Mat{#1}}{#2}}       % con subindices y paréntesis
# \newcommand{\VectFPE}[2]{\elemLPE{\Mat{#1}}{#2}}       % con subindices y paréntesis exterior
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# \newcommand{\mat}[1]{\mathbf{#1}}
# %\newcommand{\mat}[1]{\boldsymbol{#1}}                 % hace cursiva, no me gusta para matriz
# \newcommand{\Mat} [2][{}]{{\mat{#2}}_{#1}}
# \newcommand{\T}{\intercal}
# \newcommand{\MatT}[2][{}]{{\mat{#2}}^{\T}_{#1}}
# \newcommand{\VectCC}[2][{}]   {\elemRR {\Mat{#2}}{#1}}   % con ()
# \newcommand{\VectCCC}[2][{}]  {\elemRRR{\Mat{#2}}{#1}}   % con texto "col"
# %SELECCIÓNA de FILAS y COlUMNAS DE UNA MATRIZ TRANSPUESTA PARA GENERAR UN VECTOR DE Rn
# \newcommand{\VectTC}[2][{}]   {\elemR{\MatT{#2}\!}{#1}}  % con subindices
# \newcommand{\VectTCC}[2][{}]  {\elemRR{ \MatT{#2}}{#1}}  % con ()
# \newcommand{\VectTCCC}[2][{}] {\elemRRR{\MatT{#2}}{#1}}  % con texto "col"
# \newcommand{\dotprod}[2][{}] {\Vect{#1}\cdot\Vect{#2}}
# \newcommand{\concat}{\mathbin{-\mkern-9.5mu\lVert}}
# $
#
# Para usar [NAcAL](https://github.com/mbujosab/nacallib), es necesario importar el módulo `nacal`.

# %%
from nacal import *

# %% [markdown]
# Primero, lea la [Sección 1.5](https://mbujosab.github.io/CursoDeAlgebraLineal/libro.pdf#section.1.5) y la [Sección 1.6](https://mbujosab.github.io/CursoDeAlgebraLineal/libro.pdf#section.1.6) de la Lección 1 del libro.

# %% [markdown]
# ## Producto punto

# %% [markdown]
# Con el siguiente código generamos dos vectores de $\R[4]$.

# %%
a = Vector([10,2,5,4])
b = Vector([-1,5,-3,4])

# %% [markdown]
# Ahora creamos una lista con los *productos componente a componente* de ambos vectores (recorriendo las componentes desde la primera hasta la última). Después, con `sum` sumamos los elementos de la lista:

# %%
lista_de_productos_cruzados = [(a|i)*(b|i) for i in range(1, 5) ]

print(lista_de_productos_cruzados)

sum(lista_de_productos_cruzados)

# %% [markdown]
# Estas son las operaciones que realiza el producto punto entre dos vectores de $\R[n]$

# %%
a*b

# %% [markdown]
# Verifique con ejemplos las propiedades del Ejercicio 1 de la [Sección 2.1](https://mbujosab.github.io/CursoDeAlgebraLineal/libro.pdf#section.2.1) del libro.

# %% [markdown]
# Verifique con ejemplos que el producto punto también es lineal en el segundo argumento.

# %% [markdown]
# Verifique con ejemplos el **Caso 1** de la [Sección 2.1](https://mbujosab.github.io/CursoDeAlgebraLineal/libro.pdf#section.2.1) del libro.

# %% [markdown]
# ## Combinación lineal de vectores

# %% [markdown]
# Considere los vectores
# $$\Vect{x}=(1, 1, -2,),\quad \Vect{y}=(1, -2, 1,)\quad \text{y}\quad \Vect{z}=(-2, 1, 1,).$$
# Verifique que $2\Vect{x}+2\Vect{y}+2\Vect{z}=\Vect{0}$

# %%
x=Vector([1,1,-2])
y=Vector([1,-2,1])
z=Vector([-2,1,1])

2*x + 2*y + 2*z

# %% [markdown]
# Escriba el vector $\Vect{x}=(1, 1, -2,)$ explícitamente como una combinación lineal de las columnas de la matriz identidad de orden 3.

# %% [markdown]
# ### Producto de una matriz por un vector

# %% [markdown]
# Considere la siguiente matriz $\Mat{A}$ (creada mediante la [comprensión de dos listas](https://ellibrodepython.com/list-comprehension-python)).

# %%
A = Matrix( [[i-j  for j in range(3)] for i in range(4) ]  ) # range recorre los enteros de 0 a p-1 (tal como se ve en la primera columna)
A

# %% [markdown]
# Ahora calcule la siguiente combinación lineal de las columnas de $\Mat{A}$:
# $$
# 2 \elemR{\Mat{A}}{1} - 3 \elemR{\Mat{A}}{2} - 2 \elemR{\Mat{A}}{3}
# $$
# haciendo uso explícito de las columnas de la matriz en la expresión que use (es decir, transcribiendo literalmente de la expresión de arriba a código `nacal`; recuerde que $2\elemR{\Mat{A}}{1}$ es un producto, por lo que su transcripción es `2*(A|1)`, es decir, es necesario indicar la operación producto con `*`).

# %% [markdown]
# El siguiente vector contiene los coeficientes (los escalares que multiplican a las columnas) de la combinación lineal.

# %%
b = Vector( [2,-3,-2] )

# %% [markdown]
# Podemos calcular uno por uno los elementos de esta combinación lineal de columnas. Para ello calculamos el producto punto de cada una de las filas de $\Mat{A}$ por $\Vect{b}$. Por ejemplo, el primer número de la combinación lineal es:

# %%
(1|A)*b

# %% [markdown]
# Y el segundo

# %%
(2|A)*b

# %% [markdown]
# Podemos calcular todos los elementos recorriendo todas las filas de $\Mat{A}$ mediante la [comprensión de listas](https://ellibrodepython.com/list-comprehension-python).

# %%
Vector( [ (i|A)*b  for i in  range(1, A.m+1) ] )

# %% [markdown]
# Pero, con diferencia, lo más cómodo es escribir el producto de $\Mat{A}$ por el vector $\Vect{b}$

# %%
A*b

# %% [markdown]
# El primer método que hemos usado (la combinación lineal explícita) es literalmente la definición de matriz por vector que hemos visto en el [libro](https://mbujosab.github.io/CursoDeAlgebraLineal/libro.pdf#subsection.2.2.2) (y es como la librería lo calcula `A*b`).
#
# La demostración de que `(i|A)*b` es igual que `i|(A*b)` la tiene propuesta como ejercicio en la misma sección del libro.

# %% [markdown]
# #### Propiedades del producto de una matriz por un vector

# %% [markdown]
# Verifique con ejemplos que se cumplen todas las proposiciones, corolarios y reglas de reescritura que aparecen en la [sección 2.2.3](https://mbujosab.github.io/CursoDeAlgebraLineal/libro.pdf#subsection.2.2.3) del libro.
#
# No olvide escribir el símbolo `*` del producto siempre que haya un producto, y no olvide poner paréntesis donde sea necesario (añada al notebook todas las celdas de código (*code cells*) que necesite).

# %% [markdown]
# ### Producto de un vector por una matriz

# %% [markdown]
# Considere la siguiente matriz $\Mat{D}$ (creada mediante la [comprensión de dos listas](https://ellibrodepython.com/list-comprehension-python)).

# %%
D = Matrix( [[2*i-j  for j in range(4)] for i in range(3) ]  ) # range recorre los enteros de 0 a p-1 (tal como se ve en la primera columna)
D

# %% [markdown]
# Ahora calcule la siguiente combinación lineal de las filas de $\Mat{D}$:
# $$
# -fila_{1}(\Mat{D}) - 2 fila_{2}(\Mat{D}) + 3 fila_{3}(\Mat{D})
# $$
# haciendo uso explícito de las filas de la matriz en la expresión que use (es decir, transcribiendo literalmente de la expresión de arriba a código `nacal`; recuerde que $2 fila_{1}(\Mat{D})$ es un producto, por lo que su transcripción es `2*(1|D)`, es decir, es necesario indicar la operación producto con `*`).

# %%
(1|D) - 2*(2|D) + 3*(3|D)

# %% [markdown]
# El siguiente vector contiene los coeficientes (los escalares que multiplican a las columnas) de la combinación lineal.

# %%
c = Vector( [1,-2,3] )

# %% [markdown]
# Podemos calcular uno por uno los elementos de esta combinación lineal de columnas. Para ello calculamos el producto punto de cada una de las filas de $\Mat{A}$ por $\Vect{b}$. Por ejemplo, el primer número de la combinación lineal es:

# %%
c*(D|1)

# %% [markdown]
# Y el segundo

# %%
c*(D|2)

# %% [markdown]
# Podemos calcular todos los elementos recorriendo todas las filas de $\Mat{D}$ mediante la [comprensión de listas](https://ellibrodepython.com/list-comprehension-python).

# %%
Vector( [ c*(D|j)  for j in  range(1, D.n+1) ] )

# %% [markdown]
# Pero, con diferencia, lo más cómodo es escribir el producto de $\Mat{A}$ por el vector $\Vect{b}$

# %%
c*D

# %% [markdown]
# El primer método que hemos usado (la combinación lineal explícita) es literalmente la definición de vector por matriz que hemos visto en el [libro](https://mbujosab.github.io/CursoDeAlgebraLineal/libro.pdf#subsection.2.3) (y es como la librería lo calcula `c*D`).
#
# Trate de demostrar formalmente que  `c*(D|j)` es igual que `(c*D)|j`.

# %% [markdown]
# #### Propiedades del producto de una matriz por un vector

# %% [markdown]
# Verifique con ejemplos que se cumplen todas las propiedades del producto de un vector por una matriz que aparecen en la [sección 2.3.1](https://mbujosab.github.io/CursoDeAlgebraLineal/libro.pdf#https://mbujosab.github.io/CursoDeAlgebraLineal/libro.pdf#subsection.2.3.1) del libro.
#
# No olvide escribir el símbolo `*` del producto siempre que haya un producto, y no olvide poner paréntesis donde sea necesario (añada al notebook todas las celdas de código (*code cells*) que necesite).

# %% [markdown]
# Compruebe que `A*b` es igual que `b*(~A)`. Y que `c*D` es igual que `(~D)*c`. ¿Es cierto siempre? ¿Por que?
