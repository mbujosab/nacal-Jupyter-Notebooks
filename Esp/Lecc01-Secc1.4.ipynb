# %% [markdown]
# Lección 01 - Sección 1.4
# ========================
#
# **Author:** Marcos Bujosa

# %% [markdown]
# $
# \newcommand{\R}[1][{}]{{\mathbb{R}}^{#1}}
# \newcommand{\Z}[1][{}]{{\mathbb{Z}}^{#1}}
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# \newcommand{\getItem}{{\mid}}
# \newcommand{\getitemR}[1]{\getItem{#1}}
# \newcommand{\getitemL}[1]{{#1}\getItem}
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# \newcommand{\elemR}[2]{{#1}^{\phantom{\T}}_{\getitemR{#2}}}
# \newcommand{\elemRP}[2]{{\big(#1\big)}^{\phantom{\T}}_{\getitemR{#2}}}
# \newcommand{\elemRPE}[2]{\big({#1}^{\phantom{\T}}_{\getitemR{#2}}\big)}
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# \newcommand{\elemL}[2]  { {\vphantom{#1}}_{ \getitemL{#2}} {#1} }
# \newcommand{\elemLP}[2] { \elemL{\!\big({#1}\big)}{#2} }
# \newcommand{\elemLPE}[2]{ \big(\elemL{#1}{#2}\big) }
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# \newcommand{\Vect}[2][{}]{{\boldsymbol{#2}}_{#1}}
# \newcommand{\eleVR}[2]  {\elemR  {\Vect{#1}}{#2}}      % con subindices
# \newcommand{\eleVRP}[2] {\elemRP {\Vect{#1}}{#2}}      % con subindices y paréntesis interior
# \newcommand{\eleVRPE}[2]{\elemRPE{\Vect{#1}}{#2}}      % con subindices y paréntesis exterior
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# \newcommand{\VectC}[2]  {\elemR  {\Mat{#1}}{#2}}         % con subindices
# \newcommand{\VectCP}[2] {\elemRP {\Mat{#1}}{#2}}       % con subindices y paréntesis
# \newcommand{\VectCPE}[2]{\elemRPE{\Mat{#1}}{#2}}       % con subindices y paréntesis exterior
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# \newcommand{\VectF}[2]  {\elemL  {\Mat{#1}}{#2}}         % con subindices
# \newcommand{\VectFP}[2] {\elemLP {\Mat{#1}}{#2}}       % con subindices y paréntesis
# \newcommand{\VectFPE}[2]{\elemLPE{\Mat{#1}}{#2}}       % con subindices y paréntesis exterior
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# \newcommand{\mat}[1]{\mathbf{#1}}
# %\newcommand{\mat}[1]{\boldsymbol{#1}}                 % hace cursiva, no me gusta para matriz
# \newcommand{\Mat} [2][{}]{{\mat{#2}}_{#1}}
# \newcommand{\T}{\intercal}
# \newcommand{\MatT}[2][{}]{{\mat{#2}}^{\T}_{#1}}
# \newcommand{\VectCC}[2][{}]   {\elemRR {\Mat{#2}}{#1}}   % con ()
# \newcommand{\VectCCC}[2][{}]  {\elemRRR{\Mat{#2}}{#1}}   % con texto "col"
# %SELECCIÓNA de FILAS y COlUMNAS DE UNA MATRIZ TRANSPUESTA PARA GENERAR UN VECTOR DE Rn
# \newcommand{\VectTC}[2][{}]   {\elemR{\MatT{#2}\!}{#1}}  % con subindices
# \newcommand{\VectTCC}[2][{}]  {\elemRR{ \MatT{#2}}{#1}}  % con ()
# \newcommand{\VectTCCC}[2][{}] {\elemRRR{\MatT{#2}}{#1}}  % con texto "col"
# \newcommand{\dotprod}[2][{}] {\Vect{#1}\cdot\Vect{#2}}
# \newcommand{\concat}{\mathbin{-\mkern-9.5mu\lVert}}
# $
#
# Para poder usar [NAcAL](https://github.com/mbujosab/nacallib) es necesario importar el módulo `nacal`

# %%
from nacal import *

# %% [markdown]
# *Lea primero la [Sección 1.4](https://mbujosab.github.io/CursoDeAlgebraLineal/libro.pdf#section.1.4) de la Lección 1 del libro.*
# ([https://mbujosab.github.io/CursoDeAlgebraLineal](https://mbujosab.github.io/CursoDeAlgebraLineal))

# %% [markdown]
# ## Matrices de $\R[m\times n]$

# %% [markdown]
# ### Definiendo matrices

# %% [markdown]
# La notación indicada en el [libro](https://mbujosab.github.io/CursoDeAlgebraLineal/libro.pdf#section.1.4) establece que al encerrar entre corchetes una lista de vectores (con el mismo número de componentes) se denota la matriz cuyas columnas son dichos vectores. [NAcAL](https://github.com/mbujosab/nacallib) implementa este convenio utilizando una lista o tupla de vectores (con el mismo número de componentes) como argumento de la clase `Matrix()`.
#
# Así, al encerrar los vectores $(1, 2,)$, $(1, 0,)$, y $(9, 2,)$ entre corchetes se denota la matriz de $\R[2\times 3]$:
#
# $$\begin{bmatrix}1&1&9\\2&0&2\end{bmatrix}$$

# %% [markdown]
# Con [NAcAL](https://github.com/mbujosab/nacallib) logramos lo mismo colocando dicha lista de vectores como argumento de la clase `Matrix( )`

# %%
a = Vector( [1,2] )
b = Vector( [1,0] )
c = Vector( [9,2] )

D = Matrix( [a,b,c] )

# %%
print(D)              # representación de la matriz en consola
display(D)            # representación de la matriz en Jupyter Notebook

# %% [markdown]
# La representación con `repr(D)` indica explícitamente que `D` es una matriz formada por una lista de vectores, cada uno formado por una lista de números:

# %%
repr(D)              # representación más explícita

# %% [markdown]
# #### Una forma de instanciar distinta de la del libro, pero más cómoda al trabajar con el ordenador

# %% [markdown]
# Podemos instanciar una matriz mediante una lista (o tupla) de listas o tuplas. En este caso, describimos la matriz fila a fila:

# %%
A = Matrix( ( [1,1], [2,4], [3,9] ) )
A

# %% [markdown]
# Esta forma alternativa de definir matrices (*fila a fila* en lugar de *columna a columna*) resulta más cómoda al usar [NAcAL](https://github.com/mbujosab/nacallib) (aunque no es la descrita en el [libro](https://mbujosab.github.io/CursoDeAlgebraLineal/libro.pdf#section.1.4)).

# %% [markdown]
# ### Algunos atributos y procedimientos de `Matrix()`

# %% [markdown]
# #### Atributo: `.lista`

# %% [markdown]
# [NAcAL](https://github.com/mbujosab/nacallib) almacena la lista ordenada de vectores (*de columnas*) de cada `Matrix()` en su atributo `.lista`.

# %%
print( A.lista )

# %% [markdown]
# Fíjese que, aunque definimos la matriz `A` *fila a fila*, el atributo `.lista` almacena la correspondiente lista de columnas (respetando de este modo la definición de matriz dada en el curso).

# %% [markdown]
# #### El Orden de la matriz (atributos: `.m` y `.n`)

# %% [markdown]
# El atributo `.m` nos indica el número de filas de la matriz y el atributo `.n` su número de columnas. Así, el orden de $\Mat{A}$ es

# %%
print( A.m )
print( A.n )

# %% [markdown]
# #### Método: `.sis()`

# %% [markdown]
# Podemos representar una matriz en la forma genérica de un `Sistema()` con `.sis()`.

# %%
A.sis()

# %%
print(A.sis())

# %% [markdown]
# Fíjese que `repr(A.sis())` indica que `A.sis()` es un sistema formado por una lista de vectores.

# %%
repr(A.sis())

# %% [markdown]
# Y que `repr(A)` muestra que `A` es una matriz (es decir, un sistema) formada por idéntica lista de vectores.

# %%
repr(A)

# %% [markdown]
# Así, aunque `A.sis()` y `A` son objetos de tipo distinto

# %%
B = A.sis()
print(type(A))
print(type(B))

# %% [markdown]
# y con diferente representación en `NAcAL`,

# %%
# Creamos un sistema con ambos objetos y cadenas de texto para ver A y B juntos
Sistema( ['La matriz: ', A, 'El sistema: ',B] )

# %% [markdown]
# en realidad, son el mismo objeto matemático (listas ordenadas de vectores). Por eso, si preguntamos a Python si `A` y `B` son iguales, nos responde que sí.

# %%
B==A

# %% [markdown]
# ### Seleccionando filas, columnas y componentes.

# %% [markdown]
# (Secciones [1.4.1](https://mbujosab.github.io/CursoDeAlgebraLineal/libro.pdf#subsection.1.4.1) a [1.4.4](https://mbujosab.github.io/CursoDeAlgebraLineal/libro.pdf#subsection.1.4.4) del libro)
#
# Obtengamos el vector correspondiente a la *j*-ésima columna de $\Mat{A}$ (donde $j=2$)

# %%
A|2

# %% [markdown]
# y ahora el vector correspondiente a la *i*-ésima fila de $\Mat{A}$ (donde $i=1$)

# %%
1|A

# %% [markdown]
# Podemos seleccionar la componente situada en la tercera fila y segunda columna de $\Mat{A}$ del siguiente modo:

# %%
3|A|2

# %% [markdown]
# Cuando seleccionamos la componente que está en la fila *i* y la columna *j* de una matriz, obtenemos un número.
# (recuerde que Python implementa distintos tipos de números: tipo `int` es un número entero, tipo `float` es un número con decimales y tipo `Fraction` es un número racional, es decir, un entero dividido por otro entero, y el módulo [Sympy](https://www.sympy.org/es/index.html) implementa muchos números irracionales).

# %%
type( 1|A|1 )

# %% [markdown]
# Y cuando seleccionamos una fila o una columna de una matriz, obtenemos un `Vector()`.

# %%
type( A|2 )

# %%
type( 1|A )

# %% [markdown]
# Consecuentemente, tenemos varias formas de seleccionar un componente de una `Matrix()` (véase la Sección "[1.4.4 Extensión de la notación vectorial y reglas de reescritura](https://mbujosab.github.io/CursoDeAlgebraLineal/libro.pdf#subsection.1.4.4)" del [libro](https://mbujosab.github.io/CursoDeAlgebraLineal)).

# %% [markdown]
# Por ejemplo, para obtener la componente situada en la tercera fila y segunda columna de $\Mat{A}$ podemos seguir estas tres vías (entre otras):

# %%
3|A|2

# %% [markdown]
# pero también

# %%
(A|2)|3

# %% [markdown]
# o también

# %%
2|(3|A)

# %% [markdown]
# Para entender este comportamiento, recuerde que el operador selector funciona igual por la derecha que por la izquierda **cuando opera sobre vectores**
# (pues siempre selecciona el elemento indicado de la lista de números correspondiente).
#
# Aunque tiene un comportamiento muy distinto **cuando se trata de matrices**.

# %% [markdown]
# #### El orden de ejecución de las operaciones y la necesidad de poner paréntesis.

# %% [markdown]
# En Python, la [operación OR a nivel de bits](https://wiki.python.org/moin/BitwiseOperators) `3|2` da como resultado `3`.
# Sabiendo que Python ejecuta las operaciones de izquierda a derecha,
# ¿Cuál de los códigos en las dos últimas celdas no funcionará bien si quitamos los paréntesis?

# %% [markdown]
# ## La transpuesta

# %% [markdown]
# (*[Sección 1.4.5](https://mbujosab.github.io/CursoDeAlgebraLineal/libro.pdf#subsection.1.4.5) del libro*)
#
# Usando las herramientas descritas anteriormente, disponemos de una forma de transponer $\Mat{A}$:
# introducir como argumento de `Matrix()` la lista de las listas correspondientes a sus columnas (que es la forma de describir en [NAcAL](https://github.com/mbujosab/nacallib) una matriz fila a fila).
#
# Así, si la matriz es:
# $$\Mat{D}=\begin{bmatrix}1&1&9\\2&0&2\end{bmatrix}$$ entonces su transpuesta es:

# %%
Matrix( [ (D|1).lista, (D|2).lista, (D|3).lista ] )

# %% [markdown]
# Esto se puede automatizar con un bucle que recorra las filas de la matriz (usando [list comprehension](https://ellibrodepython.com/list-comprehension-python)):

# %%
B = Matrix ( [ (D|j).lista for j in range(1,D.n+1) ] )
B

# %% [markdown]
# Si estudia el código de [NAcAL](https://github.com/mbujosab/nacallib), verá que la transposición está programada tal cual.

# %% [markdown]
# He buscado un símbolo en Python para indicar la operación de la *transposición* al estilo del símbolo $^\T$ usado en el curso.
#
# Desgraciadamente, Python tiene una fuerte limitación en cuanto a la disponibilidad de símbolos para ser usados como ["métodos mágicos"](https://realpython.com/python-magic-methods/), así que no he encontrado mejor solución que emplear el símbolo (`~`) para la transposición (en lugar del símbolo $^\T$).
#
# Desafortunadamente, dicho símbolo ha de situarse *delante* de la matriz que se quiere transponer.
# Por lo tanto, en [NAcAL](https://github.com/mbujosab/nacallib), la transpuesta $\MatT{D}$ se escribe así: `~D`

# %%
~D

# %% [markdown]
# Verifiquemos que al trasponer cambian de lado los índices de los elementos de la matriz:

# %%
1|(D)|3

# %%
3|(~D)|1

# %%
3|(~D) == D|3 # la fila 3 de D transpuesta es igual que la columna 3 de D

# %%
(~D)|2 == 2|D # la columna 2 de D transpuesta es igual que la columna 2 de D

# %% [markdown]
# Si queremos obtener una matriz cuya única *columna* es la segunda fila de $\Mat{D}$, basta instanciar una `Matrix` usando una lista que contenga dicha fila:

# %%
Matrix( [2|D] )

# %% [markdown]
# ¿Cómo haría si lo que quiere obtener es la matriz cuya única *fila* es la segunda fila de $\Mat{D}$?:

# %% [markdown]
# (*al final de este notebook verá otra forma de lograr dicha matriz de una manera más compacta usando como argumento, en lugar de un índice, una tupla con un único índice)*)
#
# Compruebe que la transpuesta de la transpuesta de $\Mat{D}$ es $\Mat{D}$

# %% [markdown]
# ## Definición de algunas matrices especiales

# %% [markdown]
# (*[Sección 1.4.6](https://mbujosab.github.io/CursoDeAlgebraLineal/libro.pdf#subsection.1.4.6) del libro*)

# %% [markdown]
# ### Matriz nula

# %% [markdown]
# Con `M0(m,n)` generamos una matriz nula de orden $m$ por $n$. Por ejemplo

# %%
M0(2,3)

# %% [markdown]
# ### Matriz identidad

# %% [markdown]
# Con `I(m)` generamos una matriz identidad de orden $m$. Por ejemplo

# %%
I(2)

# %% [markdown]
# ### Matriz opuesta

# %% [markdown]
# Con el signo `-` delante de una matriz, obtenemos su opuesta

# %%
-A

# %% [markdown]
# ### Matriz diagonal

# %% [markdown]
# El método `.diag()` de `Vector()` devuelve una matriz diagonal cuadrada cuya diagonal principal contiene las componentes del vector empleado.

# %%
v = Vector( [1,2,3,4] )
v.diag()

# %% [markdown]
# A su vez, el método `.diag()` de `Matrix()` devuelve un `Vector()` con las componentes de la diagonal principal de la matriz.

# %%
Matrix( ( [1,1,1],[2,4,8], [3,9,0] ) )

# %%
Matrix( ( [1,1,1],[2,4,8], [3,9,0] ) ).diag()

# %% [markdown]
# ### Métodos que indican la forma de la matriz

# %% [markdown]
# Disponemos de algunos métodos que nos indican si es cierto que una matriz es cuadrada o si es simétrica

# %%
display(A)
A.es_cuadrada()

# %%
I(6).es_simetrica()

# %% [markdown]
# ## Definiendo una matriz a partir de las componentes de otra

# %% [markdown]
# (*Esta parte corresponde al [Apéndice](https://mbujosab.github.io/CursoDeAlgebraLineal/libro.pdf#section.alph1.1.Alph1) de la Lección 1 del libro*)
#
# Cuando seleccionamos varios componentes con una tupla obtenemos una submatriz.
# Veámoslo

# %%
B = Matrix( ( [1,1,1], [2,4,8], [3,9,0] ) )
B

# %%
B|(1,3,)

# %%
(2,3,)|B

# %%
(2,3,)|B|(1,3,)

# %%
B|(1,1,1,1,1,)

# %% [markdown]
# Tenga en cuenta que en Python `(2)` es el número `2` entre paréntesis, pero `(2,)` es una tupla con un único componente (el `2`).
#
# La diferencia es la coma "`,`" detrás del número.
#
# En el [libro](https://mbujosab.github.io/CursoDeAlgebraLineal/libro.pdf) se ha adoptado el mismo convenio de notación para poder distinguir entre números y vectores de $\R[1]$.

# %%
type( (2) )

# %%
type( (2,) )

# %% [markdown]
# `NAcAL` tiene un comportamiento muy distinto si el índice que selecciona una columna (o una fila) está dentro de una tupla o no lo está. Aquí el índice de la derecha es un número, por lo que seleccionamos la tercera columna, que es un vector:

# %%
(3,2,1,)|B|3

# %% [markdown]
# Aquí el índice de la derecha está dentro de una tupla, por lo que creamos una *matriz* columna:

# %%
(3,2,1,)|B|(3,)

# %% [markdown]
# Fíjese que si a partir de la matriz $\Mat{D}$

# %%
D

# %% [markdown]
# queremos definir la matriz cuya única fila es la segunda de $\Mat{D}$, lo podemos hacer así:

# %%
(2,)|D

# %% [markdown]
# que es más compacto que escribir `~Matrix([2|D])`.
#
# Usando la misma idea, ¿cómo obtendría la matriz cuya única columna es la tercera columna de $\Mat{D}$ de manera alternativa a `Matrix([D|3])`?
